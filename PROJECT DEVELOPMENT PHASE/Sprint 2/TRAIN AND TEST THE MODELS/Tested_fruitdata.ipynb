# %%
test_dir=r'/content/drive/MyDrive/Dataset Plant Disease/fruit-dataset/fruit-dataset/test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r"/content/drive/MyDrive/fruitdata.h5")

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
img=image.load_img(r"/content/drive/MyDrive/Dataset Plant Disease/fruit-dataset/fruit-dataset/train/Corn_(maize)___healthy/15bd6d09-98af-40f4-b098-77ec403911d4___R.S_HL 7926 copy.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F0E2B1BC0D0>

# %%
img=image.load_img(r"/content/drive/MyDrive/Dataset Plant Disease/fruit-dataset/fruit-dataset/train/Corn_(maize)___healthy/15bd6d09-98af-40f4-b098-77ec403911d4___R.S_HL 7926 copy.jpg",target_size=(128,128))
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F0E2B1EB150>

# %%
x=image.img_to_array(img)
x
# Out:
# array([[[123., 147.,  99.],
#         [127., 151., 103.],
#         [124., 147., 101.],
#         ...,
#         [128., 161., 108.],
#         [139., 172., 119.],
#         [133., 166., 113.]],
#
#        [[131., 157., 110.],
#         [131., 157., 110.],
#         [123., 149., 104.],
#         ...,
#         [128., 158., 106.],
#         [133., 163., 111.],
#         [142., 172., 120.]],
#
#        [[136., 163., 120.],
#         [126., 153., 110.],
#         [133., 160., 117.],
#         ...,
#         [153., 183., 131.],
#         [139., 169., 117.],
#         [140., 170., 118.]],
#
#        ...,
#
#        [[151., 176., 144.],
#         [147., 172., 140.],
#         [151., 177., 142.],
#         ...,
#         [ 94., 122.,  74.],
#         [ 79., 107.,  59.],
#         [ 91., 119.,  71.]],
#
#        [[136., 161., 131.],
#         [139., 164., 132.],
#         [143., 168., 136.],
#         ...,
#         [100., 128.,  80.],
#         [ 89., 117.,  69.],
# ...

# %%
x=np.expand_dims(x,axis=0)
x
# Out:
# array([[[[123., 147.,  99.],
#          [127., 151., 103.],
#          [124., 147., 101.],
#          ...,
#          [128., 161., 108.],
#          [139., 172., 119.],
#          [133., 166., 113.]],
#
#         [[131., 157., 110.],
#          [131., 157., 110.],
#          [123., 149., 104.],
#          ...,
#          [128., 158., 106.],
#          [133., 163., 111.],
#          [142., 172., 120.]],
#
#         [[136., 163., 120.],
#          [126., 153., 110.],
#          [133., 160., 117.],
#          ...,
#          [153., 183., 131.],
#          [139., 169., 117.],
#          [140., 170., 118.]],
#
#         ...,
#
#         [[151., 176., 144.],
#          [147., 172., 140.],
#          [151., 177., 142.],
#          ...,
#          [ 94., 122.,  74.],
#          [ 79., 107.,  59.],
#          [ 91., 119.,  71.]],
#
#         [[136., 161., 131.],
#          [139., 164., 132.],
#          [143., 168., 136.],
#          ...,
#          [100., 128.,  80.],
# ...

# %%
y=np.argmax(model.predict(x),axis=1)
# Out:
# 1/1 [==============================] - 0s 343ms/step

# %%
index=['Apple___Black_rot','Apple___healthy','Corn_(maize)___Northern_Leaf_Blight','Corn_(maize)___healthy','Peach___Bacterial_spot','Peach___healthy']
index[y[0]]
# Out:
# 'Corn_(maize)___healthy'

# %%
img=image.load_img(r"/content/drive/MyDrive/Dataset Plant Disease/fruit-dataset/fruit-dataset/train/Corn_(maize)___healthy/15bd6d09-98af-40f4-b098-77ec403911d4___R.S_HL 7926 copy.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 'Corn_(maize)___Northern_Leaf_Blight'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 182s 4s/step - loss: 654.0643 - accuracy: 0.6590
# [654.0642700195312, 0.6589999794960022]
