# %%
test_dir=r'/content/drive/MyDrive/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'/content/drive/MyDrive/vegetabledata.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3416 images belonging to 9 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"/content/drive/MyDrive/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Potato___Early_blight/b7883606-5157-4dc1-b965-fc10f8fe1796___RS_Early.B 7598.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FE776937150>

# %%
img=image.load_img(r"/content/drive/MyDrive/Dataset Plant Disease/Veg-dataset/Veg-dataset/test_set/Potato___Early_blight/b7883606-5157-4dc1-b965-fc10f8fe1796___RS_Early.B 7598.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %%
index=['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Potato___healthy','Potato___Late_blight','Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']
index[y[0]]
# Out:
# 'Tomato___Septoria_leaf_spot'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 209s 4s/step - loss: 2238.9419 - accuracy: 0.3420
# [2238.94189453125, 0.34200000762939453]
